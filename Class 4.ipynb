# %% [markdown]
# # Doubly Linked List
#
# A Doubly Linked List is also known as a bi-directional list. It is comprised of `nodes` that keep and maintain a reference to the `previous` node in the collection, as well as the `next` node in the collection.

# %%
# From scratch impelentation of Doubly Linked List

class DoublyLinkedList:
    class __Node:
        def __init__(self, data):
            self.prev = None
            self.next = None
            self.data = data

    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, value):
        new_node = self.__Node(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
        
    def insert(self, index, value):
        # this inserts a new node with the given value BEFORE the target index
        # Note: There are some additional consideration for the combinations of "index" and the state of our list.
        
        pass

    def remove(self, value):
        # this removes the *first* instance of the given value

        #find the length of the nodes
        #set node to zero 

        #create r
        
        pass

    def index(self, value):
        # This returns the *first* index of the given value
        
        # look for first node on list
            # set node to the head

        # move to next index
            # increase increase by 1

        # if index is equal to 1
            # print
            # if not increase by 1

        pass

    def __get__(self, index):
        # this method allows you to use square bracket notation to retrieve a value at the target index (IE dll[5])
        pass

    def __set__(self, index, value):
        # this method allows you to use square bracket notation to insert a node into the list (IE dll[5] = "A")
        pass

    def __len__(self):
        # this will return the number of Nodes in our list
        count = 0 
        current = self.head
        while current:
            count += 1
            current = current.next
        return count

    def __bool__(self):
        # this will help evaluate our list with "if" and "if not"
        return self.head != None

    def inverted(self):
        # this method allows us to print (or return a string) of our list, but in inverted order
        pass

    def __str__(self):
        # This method must return a string
        out = "["
        current = self.head
        if current:
            out += "%s" % repr(current.data)
            while current.next:
                current = current.next
                out += ", %s" % repr(current.data)
        out += "]"
        return out

# %%
# Comparing python3 lists to our DLL implementation
pylist = []
dll = DoublyLinkedList()

# Empty list:
print("Empty python list: %s" % pylist)
print("Empty DLL: %s" % dll)

# Our lists with exactly one element:
pylist.append(0)
dll.append(0)
print("Python list with one element: %s" % pylist)
print("Empty DLL: %s" % dll)

# Our lists with more than one element:
pylist.append(1)
dll.append(1)
print("Python list with more than one element: %s" % pylist)
print("DLL with more than one element: %s" % dll)

# Displaying the length of both of our lists:
print("the len of our python list: %s" % len(pylist))
print("the len of our DLL: %s" % len(dll))
# Out:
# Empty python list: []
# Empty DLL: []
# Python list with one element: [0]
# Empty DLL: [0]
# Python list with more than one element: [0, 1]
# DLL with more than one element: [0, 1]
# the len of our python list: 2
# the len of our DLL: 2
